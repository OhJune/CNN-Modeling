# %%
import tensorflow as tf
model = tf.keras.models.load_model("./cats_dogs_basic_cnn_3.h5")

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
import numpy as np
path = r"C:/workspace/cat_dog/cat.jpg"
path2 = r"C:/Users/Playdata/Desktop/dog.jpg"
data = load_img(path2, target_size=(150,150))

# %%
pip install PIL
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement PIL (from versions: none)
# ERROR: No matching distribution found for PIL

# %%
from PIL import Image

# %%
Image.open( path2, mode = 'r')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=676x512>

# %%
path2 = r"C:/Users/Playdata/Desktop/dog.jpg"
data = load_img(path2, target_size=(150,150))

# %%
data = img_to_array(data).astype('float32')

# %%
data /= 255.0

# %%
data.shape
# Out:
# (150, 150, 3)

# %%
# shape을 변경해서 모델 fit

# %%
model.predict(data.reshape(-1,150,150,3))
# Out:
# 1/1 [==============================] - 0s 369ms/step
# array([[0.00178013]], dtype=float32)

# %%
import requests
import base64
url = "http://127.0.0.1:8000/predict/"
with open(r"C:/workspace/cat_dog/cat.jpg", 'rb') as img:
    base64_string = base64.b64encode(img.read())
r = requests.post(url, data = {'image' : base64_string})
r.text
# Out:
# '{"result":"고양이 사진을 보내셨네요..."}'

# %%
import requests
import base64
url = "http://127.0.0.1:8000/predict/"
with open(r"C:/Users/Playdata/Downloads/서현.jpg", 'rb') as img:
    base64_string = base64.b64encode(img.read())
r = requests.post(url, data = {'image' : base64_string})
r.text
# Out:
# '{"result":"고양이 사진을 보내셨네요..."}'
